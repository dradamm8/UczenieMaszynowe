# %% [markdown]
# # Import wymaganych pakietów

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Wczytanie pliku

# %%
df = pd.read_csv("Zbiór danych Titanic.arff.txt", header = 0, na_values = "?")
df.head(20)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
names = ['name','sex', 'cabin', 'embarked', 'home.dest']

# %%
for name in names:
    print(f'Liczba etykiet zmiennej {name}: {len(df[name].unique())}')
# Out:
# Liczba etykiet zmiennej name: 1307
# Liczba etykiet zmiennej sex: 2
# Liczba etykiet zmiennej cabin: 187
# Liczba etykiet zmiennej embarked: 4
# Liczba etykiet zmiennej home.dest: 370

# %%
print(f"Ilość rekordów w tabeli: {len(df['name'])}")
# Out:
# Ilość rekordów w tabeli: 1309

# %% [markdown]
# Ilość unikalnych imion jest różna od ilości rekordów w tabeli. Sprawdzam czy nie występują duplikaty:

# %%
dup_names = df[df[['name']].duplicated()].name.values

# %%
df[df['name'] == dup_names[0]]
# Out:
#      pclass  survived                  name     sex   age  sibsp  parch  \
# 725       3         1  Connolly, Miss. Kate  female  22.0      0      0
# 726       3         0  Connolly, Miss. Kate  female  30.0      0      0
#
#      ticket    fare cabin embarked boat  body home.dest CabinReduced
# 725  370373  7.7500   NaN        Q   13   NaN   Ireland            n
# 726  330972  7.6292   NaN        Q  NaN   NaN   Ireland            n

# %%
df[df['name'] == dup_names[1]]
# Out:
#      pclass  survived              name   sex   age  sibsp  parch  ticket  \
# 924       3         0  Kelly, Mr. James  male  34.5      0      0  330911
# 925       3         0  Kelly, Mr. James  male  44.0      0      0  363592
#
#        fare cabin embarked boat  body home.dest CabinReduced
# 924  7.8292   NaN        Q  NaN  70.0       NaN            n
# 925  8.0500   NaN        S  NaN   NaN       NaN            n

# %% [markdown]
# Nie występują duplikaty - zduplikowane rekordy to osoby przypadkowo nazywające się tak samo.
# <b>Ilość pasażerów wynosi zatem 1309</b>.
#
# Najciekawsze wyniki dały informacje o kardynalności zmiennych <b>cabin i home.dest</b>, w których możemy zauważyć dużą ilość kategorii (wysoką kardynalność), ale o wiele mniejszą od liczby pasażerów.
# Oznacza to, że możemy spróbować dokonać redukcji kardynalności tych cech i dzięki temu uogólnić rozważania (stworzyć model wartości przeciętnej i uniknąć overfittingu).

# %% [markdown]
# <b>Cechy o małej kardynalności</b>:
# - sex
# - embarked

# %% [markdown]
# <b>Cechy o dużej kardynalności</b>:
# - cabin
# - home.dest

# %% [markdown]
# ## Redukcja kardynalności zmiennej Cabin

# %%
df['cabin'].value_counts()
# Out:
# cabin
# C23 C25 C27        6
# B57 B59 B63 B66    5
# G6                 5
# D                  4
# F4                 4
#                   ..
# F E46              1
# F E57              1
# F E69              1
# E10                1
# F38                1
# Name: count, Length: 186, dtype: int64

# %%
df['CabinReduced'] = df['cabin'].astype(str).str[0]
df[['cabin', 'CabinReduced']].head(20)
# Out:
#       cabin CabinReduced
# 0        B5            B
# 1   C22 C26            C
# 2   C22 C26            C
# 3   C22 C26            C
# 4   C22 C26            C
# 5       E12            E
# 6        D7            D
# 7       A36            A
# 8      C101            C
# 9       NaN            n
# 10  C62 C64            C
# 11  C62 C64            C
# 12      B35            B
# 13      NaN            n
# 14      A23            A
# 15      NaN            n
# 16  B58 B60            B
# 17  B58 B60            B
# 18      D15            D
# 19       C6            C

# %%
#unikalne wartości zmiennej cabin
df['cabin'].unique()
# Out:
# array(['B5', 'C22 C26', 'E12', 'D7', 'A36', 'C101', nan, 'C62 C64', 'B35',
#        'A23', 'B58 B60', 'D15', 'C6', 'D35', 'C148', 'C97', 'B49', 'C99',
#        'C52', 'T', 'A31', 'C7', 'C103', 'D22', 'E33', 'A21', 'B10', 'B4',
#        'E40', 'B38', 'E24', 'B51 B53 B55', 'B96 B98', 'C46', 'E31', 'E8',
#        'B61', 'B77', 'A9', 'C89', 'A14', 'E58', 'E49', 'E52', 'E45',
#        'B22', 'B26', 'C85', 'E17', 'B71', 'B20', 'A34', 'C86', 'A16',
#        'A20', 'A18', 'C54', 'C45', 'D20', 'A29', 'C95', 'E25', 'C111',
#        'C23 C25 C27', 'E36', 'D34', 'D40', 'B39', 'B41', 'B102', 'C123',
#        'E63', 'C130', 'B86', 'C92', 'A5', 'C51', 'B42', 'C91', 'C125',
#        'D10 D12', 'B82 B84', 'E50', 'D33', 'C83', 'B94', 'D49', 'D45',
#        'B69', 'B11', 'E46', 'C39', 'B18', 'D11', 'C93', 'B28', 'C49',
#        'B52 B54 B56', 'E60', 'C132', 'B37', 'D21', 'D19', 'C124', 'D17',
#        'B101', 'D28', 'D6', 'D9', 'B80', 'C106', 'B79', 'C47', 'D30',
# ...

# %%
print(f"Ilość etykiet zmiennej CabinReduced: {len(df['CabinReduced'].unique())}")
# Out:
# Ilość etykiet zmiennej CabinReduced: 9

# %%
print(f"Ilość etykiet względem zmiennej cabin zredukowano o {(187-9)/187*100:.2f}%")
# Out:
# Ilość etykiet względem zmiennej cabin zredukowano o 95.19%

# %%
df.groupby(["pclass", 'CabinReduced'])[['cabin']].count()
# Out:
#                      cabin
# pclass CabinReduced
# 1      A                22
#        B                65
#        C                94
#        D                40
#        E                34
#        T                 1
#        n                 0
# 2      D                 6
#        E                 4
#        F                13
#        n                 0
# 3      E                 3
#        F                 8
#        G                 5
#        n                 0

# %%
#wartości brakujące dla danych kabin:
df.groupby(['pclass', 'CabinReduced'])[['cabin']].apply(lambda x: x.isnull().sum())
# Out:
#                      cabin
# pclass CabinReduced
# 1      A                 0
#        B                 0
#        C                 0
#        D                 0
#        E                 0
#        T                 0
#        n                67
# 2      D                 0
#        E                 0
#        F                 0
#        n               254
# 3      E                 0
#        F                 0
#        G                 0
#        n               693

# %% [markdown]
# Można zauważyć, że kabiny <b>A, B, C, D, E, T</b> są powiązane z przynależnością do <b>klasy pierwszej</b>
#
# Kabiny <b>D, E, F</b> - do <b>klasy drugiej</b>
#
# Kabiny <b>E, F, G</b> - do <b>klasy trzeciej</b>
#
#
# Kabiny E występują w każdej klasie (najwięcej w pierwszej)
#
# Kabiny D - w pierwszej i drugiej
#
# Kabiny F - w druiej i trzeciej
#
# Zauważamy też, że w klasie drugiej i trzeciej tylko niewiele osób miało przydzieloną kabinę.

# %% [markdown]
# Możemy dokonać redukcji akurat tej zmiennej, ponieważ literowe oznaczenie kabiny może nieść wystarczającą informację potrzebną dla utworzenia modelu i analizy danych (np. jest to typ kabiny i świadczy o statusie społecznym danego pasażera lub o jego rodzinie).
#
# Zmiejszenie kardynalności danej cechy pozwoli nam też na oszczędzenie zasobów obliczeniowych i pamięciowych komputera (i np. przyspieszenie wykonywania zapytań).
#
# Negatywne skutki jakie mogą wystąpić są związane z tym, że obcinając numery kabin być może jednak tracimy jakąś ważną informację (np. o ich położeniu).
